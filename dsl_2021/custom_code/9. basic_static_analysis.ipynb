# %%
# 기초통계
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
cd "data/csv_data/50/엑셀_분석용_데이터마트/"
# Out:
# C:\Users\dudtj\busan_moving_person\data\csv_data\50\엑셀_분석용_데이터마트

# %%
df = pd.read_csv("fillna_dataset_monthly_total_fp.csv", encoding="UTF-8")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227440 entries, 0 to 227439
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            227440 non-null  int64
#  1   x             227440 non-null  int64
#  2   y             227440 non-null  int64
#  3   timezn_cd     227440 non-null  int64
#  4   total_201901  227440 non-null  float64
#  5   total_201902  227440 non-null  float64
#  6   total_201903  227440 non-null  float64
#  7   total_201904  227440 non-null  float64
#  8   total_201905  227440 non-null  float64
#  9   total_201906  227440 non-null  float64
#  10  total_201907  227440 non-null  float64
#  11  total_201908  227440 non-null  float64
#  12  total_201909  227440 non-null  float64
#  13  total_201910  227440 non-null  float64
#  14  total_201911  227440 non-null  float64
#  15  total_201912  227440 non-null  float64
# dtypes: float64(12), int64(4)
# memory usage: 27.8 MB

# %%
new_df = df.drop(columns=['id', 'x', 'y'])

# %%
new_df = new_df.groupby('timezn_cd').sum()

# %%
new_df
# Out:
#            total_201901  total_201902  total_201903  total_201904  \
# timezn_cd
# 0            1350240.75    1315018.54    1390014.33    1177912.19
# 1            1561039.02    1515863.94    1603947.85    1385412.84
# 2            1518775.60    1475974.74    1563130.94    1346799.05
# 3            1475328.92    1433788.30    1519295.39    1308119.23
# 4            1422194.63    1378546.18    1468401.13    1258194.73
# 5            1405267.42    1357838.60    1457989.42    1247984.28
# 6            1849456.23    1735593.43    1904743.91    1716566.98
# 7            2228192.25    2077824.80    2334051.39    2154430.34
# 8            2712950.03    2502739.31    2889679.25    2714655.99
# 9            3251107.85    2956075.37    3425222.40    3247876.69
# 10           3647539.29    3296089.06    3816832.92    3638324.23
# 11           3950443.29    3557689.39    4116395.76    3930214.22
# 12           4259791.36    3821046.49    4418121.80    4219979.92
# ...
