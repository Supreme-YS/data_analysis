# %%
import pandas as pd
import numpy as np
import os
from tqdm.notebook import tqdm

# %%
path = f"C:\\Users\\dudtj\\busan_moving_person\\data\\csv_data" #원천데이터 파일위치
os.chdir(path)
file_list = os.listdir(path)
f_list = [file for file in file_list if file.endswith(".csv")]
print(f_list)
print(type(f_list))
# Out:
# ['50CELL_BUSANJINGU_2019_201901.csv', '50CELL_BUSANJINGU_2019_201902.csv', '50CELL_BUSANJINGU_2019_201903.csv', '50CELL_BUSANJINGU_2019_201904.csv', '50CELL_BUSANJINGU_2019_201905.csv', '50CELL_BUSANJINGU_2019_201906.csv', '50CELL_BUSANJINGU_2019_201907.csv', '50CELL_BUSANJINGU_2019_201908.csv', '50CELL_BUSANJINGU_2019_201909.csv', '50CELL_BUSANJINGU_2019_201910.csv', '50CELL_BUSANJINGU_2019_201911.csv', '50CELL_BUSANJINGU_2019_201912.csv']
# <class 'list'>

# %%
# 원천데이터 타입 확인
for file in f_list:
    #print(file)
    test_df = pd.read_csv(file, encoding='UTF-8')
    print(test_df.dtypes)
    print("-------------------------------------------------")
# Out:
# id             int64
# x              int64
# y              int64
# timezn_cd      int64
# m00          float64
# m10          float64
# m15          float64
# m20          float64
# m25          float64
# m30          float64
# m35          float64
# m40          float64
# m45          float64
# m50          float64
# m55          float64
# m60          float64
# m65          float64
# m70          float64
# f00          float64
# f10          float64
# f15          float64
# f20          float64
# f25          float64
# f30          float64
# f35          float64
# f40          float64
# f45          float64
# f50          float64
# f55          float64
# f60          float64
# f65          float64
# f70          float64
# total        float64
# admi_cd        int64
# etl_ymd        int64
# dtype: object
# -------------------------------------------------
# id             int64
# x              int64
# y              int64
# timezn_cd      int64
# m00          float64
# ...

# %%
# 500셀 데이터 타입 확인
path = f"C:\\Users\\dudtj\\busan_moving_person\\data\\csv_data\\500" #원천데이터 파일위치
os.chdir(path)
file_list = os.listdir(path)
f_list = [file for file in file_list if file.endswith(".csv")]
print(f_list)
print(type(f_list))

for file in f_list:
    #print(file)
    test_df = pd.read_csv(file, encoding='UTF-8')
    print(test_df.dtypes)
    print("-------------------------------------------------")
# Out:
# ['CV500_50CELL_BUSANJINGU_2019_201901.csv', 'CV500_50CELL_BUSANJINGU_2019_201902.csv', 'CV500_50CELL_BUSANJINGU_2019_201903.csv', 'CV500_50CELL_BUSANJINGU_2019_201904.csv', 'CV500_50CELL_BUSANJINGU_2019_201905.csv', 'CV500_50CELL_BUSANJINGU_2019_201906.csv', 'CV500_50CELL_BUSANJINGU_2019_201907.csv', 'CV500_50CELL_BUSANJINGU_2019_201908.csv', 'CV500_50CELL_BUSANJINGU_2019_201909.csv', 'CV500_50CELL_BUSANJINGU_2019_201910.csv', 'CV500_50CELL_BUSANJINGU_2019_201911.csv', 'CV500_50CELL_BUSANJINGU_2019_201912.csv']
# <class 'list'>
# id              int64
# x               int64
# y               int64
# timezn_cd       int64
# m00           float64
# m10           float64
# m15           float64
# m20           float64
# m25           float64
# m30           float64
# m35           float64
# m40           float64
# m45           float64
# m50           float64
# m55           float64
# m60           float64
# m65           float64
# m70           float64
# f00           float64
# ...

# %%
# 500셀 데이터 타입 확인
path = f"C:\\Users\\dudtj\\busan_moving_person\\data\\csv_data\\500\\500셀_부산진구 유동인구 데이터_행정동 매칭" #원천데이터 파일위치
os.chdir(path)
file_list = os.listdir(path)
f_list = [file for file in file_list if file.endswith(".csv")]
print(len(f_list))
print(type(f_list))

for file in f_list:
    #print(file)
    test_df = pd.read_csv(file, encoding='UTF-8')
    print(test_df.dtypes)
    print("-------------------------------------------------")
# Out:
# 12
# <class 'list'>
# id              int64
# x               int64
# y               int64
# timezn_cd       int64
# m00           float64
# m10           float64
# m15           float64
# m20           float64
# m25           float64
# m30           float64
# m35           float64
# m40           float64
# m45           float64
# m50           float64
# m55           float64
# m60           float64
# m65           float64
# m70           float64
# f00           float64
# f10           float64
# f15           float64
# f20           float64
# f25           float64
# f30           float64
# f35           float64
# f40           float64
# f45           float64
# f50           float64
# f55           float64
# f60           float64
# f65           float64
# f70           float64
# total         float64
# admdong_cd      int64
# etl_ymd         int64
# admdong_nm     object
# dtype: object
# -------------------------------------------------
# id              int64
# ...
